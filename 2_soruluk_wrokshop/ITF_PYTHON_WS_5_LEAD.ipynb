# %% [markdown]
# <center><img src="https://github.com/aaron-clarusway/fullstack/blob/master/itf-logo.png?raw=true"  alt="alt text" width="200"/></center>
# <br>
# <h1><p style="text-align: center; color:darkblue">Python Basic</p><h1>
# <center><h1>Workshop - 5</h1></center>
# <p><img align="right"
#   src="https://secure.meetupstatic.com/photos/event/3/1/b/9/600_488352729.jpeg"  width="15px"></p>
# <br>
#
#
# # Subject: Collections - Control Flow Statements

# %% [markdown]
# ## Coding Challenge-1 : Find the Largest Number
#
# Purpose of the this coding challenge is to solve a simple sorting problem in Python.
#
# ### Learning Outcomes
#
# At the end of the this coding challenge, students will be able to;
#
# - get a basic understanding of sorting algorithms.
# - demonstrate their knowledge of lists in python
# - implement loops to solve the problems in python
# - get a better understanding of computational thinking concepts
#
# ### Problem Statement
#
# - Write a python code that finds the largest number among the ``n`` numbers given by the user as input.
#
# - First, take `n` from the user, then take `n` numbers one by one and select-print the largest one.
#
# - It is forbidden to use ``max()`` function.
#
# - Indicate which computational thinking concepts have you used.
#
# - Example for user inputs and respective outputs
#
# ```text
# Input                Output
# ---------------:     -------------------------:
# n = 5, 1 2 3 4 5     The largest number is:  5
# n = 3, 67 85 19      The largest number is:  85
# ```

# %% [markdown]
# ### Solution :

# %%
#Furkan Bey
def find_max(list):
    x = sorted(list)[-1]
    return x
num = int(input("How many numbers : "))
list1 = []
for i in range(0,num):
    numbers = int(input("Enter a number : "))
    list1.append(numbers)
print(f"Maximum element in the list1 is : {find_max(list1)}")
# Out:
# How many numbers : 3
# Enter a number : 12
# Enter a number : 13
# Enter a number : 14
# Maximum element in the list1 is : 14

# %%
#Faruk Bey
liste = []
adet = int(input('kac sayi girilecek...:'))
for i in range(adet):
    sayi = int(input('sayi gir...:'))
    liste.append(sayi)
buyuk = liste[0]
for j in liste:
    if j>buyuk:
        buyuk=j
print('en buyuk sayi...:',buyuk)
# Out:
# kac sayi girilecek...:3
# sayi gir...:12
# sayi gir...:13
# sayi gir...:14
# en buyuk sayi...: 14

# %%
# Teamlead Cözüm
count=0
array=[]
size = int(input("How many numbers will you enter? "))
while count < size:
    number= int(input('Please enter the number: '))
    array.append(number)
    count = count +1

largest = array[0]
for i in array:
    if i > largest:
        largest = i

print("The largest number is : ", largest)

# %%
##  Cagatay
sayac = 0 
liste=[]
while True:
    n = input("How many numbers will you enter?  ")
    if n.isdigit() == True :
        print()
        break
    else:
        print("Hatali Giris !!")
while True:
    sayi = input("Bir sayi giriniz : ")
    if sayi.isdigit() == True and int(sayi) > 0:
        liste.append(int(sayi))
        sayac += 1 
    else:
        print("Hatali Giris !!")
    
    if sayac == int(n):
        break

max=0
for i in range(int(n)):
    if liste[i] > max:
        max = liste[i]        
print()
print(f"The largest number is {max}")
# Out:
# How many numbers will you enter?  w
# Hatali Giris !!
# How many numbers will you enter?  w
# Hatali Giris !!
# How many numbers will you enter?  3
#
# Bir sayi giriniz : 12
# Bir sayi giriniz : as
# Hatali Giris !!
# Bir sayi giriniz : 13
# Bir sayi giriniz : 14
#
# The largest number is 14

# %% [markdown]
# ## Coding Challenge-2 : Group Anagrams
#
# Purpose of the this coding challenge is to solve a grouping algorithm in Python.
#
# ### Learning Outcomes
#
# At the end of the this coding challenge, students will be able to;
#
# - get a basic understanding of grouping algorithms.
# - demonstrate their knowledge of lists, dicts in python
# - implement loops to solve the problems in python
# - get a better understanding of computational thinking concepts
#
# ### Problem Statement
#
# - Given a list of strings, group anagrams together.
#
# - Example:
#
# **Input:**
# ```
# ["eat", "tea", "tan", "ate", "nat", "bat"],
# Output:
# [
#   ["ate","eat","tea"],
#   ["nat","tan"],
#   ["bat"]
# ]
# ```
# Note:
# All inputs will be in lowercase.
# The order of your output does not matter.

# %% [markdown]
# ### Solution :

# %%
#Furkan Bey
strs = ["eat", "tea", "tan", "ate", "nat", "bat", "cat", "tac"]
list1 = []
for i in strs:
  x = [j for j in strs if set(i)==set(j)]
  if x not in list1:
    list1 += [x]
print(list1)
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat'], ['cat', 'tac']]

# %%
#Halil Bey
strs = ["eat", "tea", "tan", "ate", "nat", "bat", "cat", "tac"]
# create an empty list to hold values (key:sorted word, values:words)
anagrams = {}
# iterating over the list to fill the empty dict
for word in strs:
    # sorting the words
    sorted_word = str(sorted(word))
    # checking the word in dict
    if sorted_word not in anagrams:
         # if sorted_word do not exist in the dict, assign a value as a list to this key
        anagrams[sorted_word] = [word]
    else:
        # if sorted_word exist in the dict, add word as a value to this key
        anagrams[sorted_word].append(word)
# printing dict values as a list
print(list(anagrams.values()))
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat'], ['cat', 'tac']]

# %%
# Teamlead Cözüm
strs = ["eat", "tea", "tan", "ate", "nat", "bat", "cat", "tac"]
anag = {}
for i in strs:
    element = "".join(sorted(i)) #her bir kelimenin harflerini ayristirip siraladi
    if element in anag:
        anag[element].append(i) #siraladigi harfleri key olarak aldi
    else:
        anag[element] = [i]     #burda da o key varsa i hangi kelimeyse döngüde o key e i kelimesini atadi
print(list(anag.values()))
# Out:
# aet
# aet
# {'aet': ['eat', 'tea']}
# ant
# aet
# {'aet': ['eat', 'tea', 'ate'], 'ant': ['tan']}
# ant
# {'aet': ['eat', 'tea', 'ate'], 'ant': ['tan', 'nat']}
# abt
# act
# act
# {'aet': ['eat', 'tea', 'ate'], 'ant': ['tan', 'nat'], 'abt': ['bat'], 'act': ['cat', 'tac']}
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat'], ['cat', 'tac']]

# %%
## Cagatay
liste = ["eat", "tea", "tan", "ate", "nat", "bat", "cat", "tac"]

liste_sonuc=[]

for i in liste:
    liste_ic=[]
    for j in liste:
        if set(j)==set(i):
            liste_ic.append(j)
    if(liste_ic not in liste_sonuc):
        liste_sonuc.append(liste_ic)

print(liste_sonuc)
# Out:
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat'], ['cat', 'tac']]

# %%
liste = ["eat", "tea", "tan", "ate", "nat", "bat", "cat", "tac"]

list2  =list()
for i in liste :
    list1 = list()          #list1 burda tanimlamimizin nedeni listeyi sifirlamak. Yoksa ilk döngüdeki kelimelere ekleyerek gider.
    for j in liste :
        if set(i) == set(j) :
            list1.append(j)
    print(list1)
    print()
    if list1 not in list2 :
        list2.append(list1)
print(list2)
# Out:
# ['eat', 'tea', 'ate']
#
# ['eat', 'tea', 'ate']
#
# ['tan', 'nat']
#
# ['eat', 'tea', 'ate']
#
# ['tan', 'nat']
#
# ['bat']
#
# ['cat', 'tac']
#
# ['cat', 'tac']
#
# [['eat', 'tea', 'ate'], ['tan', 'nat'], ['bat'], ['cat', 'tac']]
